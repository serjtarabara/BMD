# %% [markdown]
# <h3>Tarabara BC-81 BMD</h3>

# %% [markdown]
# Введення даних вручну

# %%
import pandas as pd

# %%
new_df = pd.DataFrame(
{
    "Iphone": ['Iphone 6', 'Iphone 6s', 'Iphone 7', 'Iphone 7+', 'Iphone 8'],
    "Year": [2014, 2015, 2016, 2016, 2017],
    "IOS_Version": [12.4, 13.1, 13.1, 13.1, 13.2],
    "Battery_volume": [1810, 1715, 1960, 2450, 1920]
})

new_df
# Out:
#       Iphone  Year  IOS_Version  Battery_volume
# 0   Iphone 6  2014         12.4            1810
# 1  Iphone 6s  2015         13.1            1715
# 2   Iphone 7  2016         13.1            1960
# 3  Iphone 7+  2016         13.1            2450
# 4   Iphone 8  2017         13.2            1920

# %% [markdown]
# Import data about COVID 19 containment measures

# %%
path = "/Users/Сергей/Desktop/COVID 19 Containment measures data.csv"
data = pd.read_csv(path, encoding = 'utf-8')

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import os

print("The directory we are working in is: {}".format(os.getcwd()))
# Out:
# The directory we are working in is: C:\Users\Сергей

# %%
data = pd.read_csv('COVID 19 Containment measures data.csv')

print(type(data))

# %%
data
# Out:
#        ID Applies To         Country    Date Start Date end intended  \
# 0     163        NaN         Austria  Mar 16, 2020               NaN
# 1     132        NaN         Germany  Feb 01, 2020               NaN
# 2     578        NaN  United Kingdom  Mar 20, 2020               NaN
# 3     372        NaN  United Kingdom  Mar 16, 2020               NaN
# 4     357        NaN  United Kingdom  Mar 16, 2020               NaN
# ...   ...        ...             ...           ...               ...
# 1031  NaN        NaN             NaN           NaN               NaN
# 1032  NaN        NaN    US: Michigan           NaN               NaN
# 1033  NaN        NaN     US:Maryland           NaN               NaN
# 1034  NaN        NaN     US:Maryland           NaN               NaN
# 1035  NaN        NaN     US:Maryland           NaN               NaN
#
#                      Description of measure implemented Exceptions  \
# 0     On 10 March 2020 government announced that all...        NaN
# ...

# %% [markdown]
# Statistics and other

# %%
data.shape
# Out:
# (1036, 16)

# %%
data.head(5)
# Out:
#     ID Applies To         Country    Date Start Date end intended  \
# 0  163        NaN         Austria  Mar 16, 2020               NaN
# 1  132        NaN         Germany  Feb 01, 2020               NaN
# 2  578        NaN  United Kingdom  Mar 20, 2020               NaN
# 3  372        NaN  United Kingdom  Mar 16, 2020               NaN
# 4  357        NaN  United Kingdom  Mar 16, 2020               NaN
#
#                   Description of measure implemented Exceptions  \
# 0  On 10 March 2020 government announced that all...        NaN
# 1  102 German citizens and 26 relatives, all of w...        NaN
# 2        All schools, nurseries and colleges closed.        NaN
# 3  If one person in any household has a persisten...        NaN
# 4  By the weekend, those with the most serious he...        NaN
#
#   Implementing City Implementing State/Province  \
# 0               NaN                         NaN
# 1               NaN                         NaN
# ...

# %%
data.tail(5)
# Out:
#        ID Applies To       Country Date Start Date end intended  \
# 1031  NaN        NaN           NaN        NaN               NaN
# 1032  NaN        NaN  US: Michigan        NaN               NaN
# 1033  NaN        NaN   US:Maryland        NaN               NaN
# 1034  NaN        NaN   US:Maryland        NaN               NaN
# 1035  NaN        NaN   US:Maryland        NaN               NaN
#
#      Description of measure implemented Exceptions Implementing City  \
# 1031                                NaN        NaN               NaN
# 1032                                NaN        NaN               NaN
# 1033                                NaN        NaN               NaN
# 1034                                NaN        NaN               NaN
# 1035                                NaN        NaN               NaN
#
#      Implementing State/Province Keywords  Quantity Source  Target city  \
# 1031                         NaN      NaN       NaN    NaN          NaN
# ...

# %%
data.dtypes
# Out:
# ID                                     object
# Applies To                             object
# Country                                object
# Date Start                             object
# Date end intended                      object
# Description of measure implemented     object
# Exceptions                             object
# Implementing City                      object
# Implementing State/Province            object
# Keywords                               object
# Quantity                              float64
# Source                                 object
# Target city                           float64
# Target country                         object
# Target region                          object
# Target state                          float64
# dtype: object

# %% [markdown]
# Object type description

# %%
data.describe(include='object')
# Out:
#                       ID Applies To Country    Date Start Date end intended  \
# count                825         25    1030          1008               163
# unique               796         24      91            81                51
# top     Copy of Untitled    Bavaria   China  Mar 16, 2020      Mar 31, 2020
# freq                   4          2      96            98                14
#
#        Description of measure implemented  \
# count                                1011
# unique                                982
# top                    state of emergency
# freq                                    7
#
#                                                Exceptions Implementing City  \
# count                                                  30                72
# unique                                                 30                42
# top     inpatient care, which is provided to minors, p...             Wuhan
# ...

# %% [markdown]
# Number type description

# %%
data.describe()
# Out:
#        Quantity  Target city  Target state
# count       0.0          0.0           0.0
# mean        NaN          NaN           NaN
# std         NaN          NaN           NaN
# min         NaN          NaN           NaN
# 25%         NaN          NaN           NaN
# 50%         NaN          NaN           NaN
# 75%         NaN          NaN           NaN
# max         NaN          NaN           NaN

# %% [markdown]
# All types description

# %%
stats = data.describe(include = 'all')

stats
# Out:
#                       ID Applies To Country    Date Start Date end intended  \
# count                825         25    1030          1008               163
# unique               796         24      91            81                51
# top     Copy of Untitled    Bavaria   China  Mar 16, 2020      Mar 31, 2020
# freq                   4          2      96            98                14
# mean                 NaN        NaN     NaN           NaN               NaN
# std                  NaN        NaN     NaN           NaN               NaN
# min                  NaN        NaN     NaN           NaN               NaN
# 25%                  NaN        NaN     NaN           NaN               NaN
# 50%                  NaN        NaN     NaN           NaN               NaN
# 75%                  NaN        NaN     NaN           NaN               NaN
# max                  NaN        NaN     NaN           NaN               NaN
#
#        Description of measure implemented  \
# ...

# %% [markdown]
# Working with smaller data

# %%
cut_data = data.iloc[0:10, :]

cut_data
# Out:
#     ID Applies To         Country    Date Start Date end intended  \
# 0  163        NaN         Austria  Mar 16, 2020               NaN
# 1  132        NaN         Germany  Feb 01, 2020               NaN
# 2  578        NaN  United Kingdom  Mar 20, 2020               NaN
# 3  372        NaN  United Kingdom  Mar 16, 2020               NaN
# 4  357        NaN  United Kingdom  Mar 16, 2020               NaN
# 5  356        NaN  United Kingdom  Mar 16, 2020               NaN
# 6  373        NaN  United Kingdom  Mar 14, 2020               NaN
# 7  355        NaN  United Kingdom  Feb 26, 2020               NaN
# 8  603        NaN  United Kingdom  Mar 18, 2020      Apr 18, 2020
# 9  NaN        NaN         Vietnam           NaN               NaN
#
#                   Description of measure implemented Exceptions  \
# 0  On 10 March 2020 government announced that all...        NaN
# 1  102 German citizens and 26 relatives, all of w...        NaN
# ...

# %%
new_data = ['Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Europe', 'Asia']
cut_data.insert(1, 'Region', new_data)
cut_data
# Out:
#     ID  Region Applies To         Country    Date Start Date end intended  \
# 0  163  Europe        NaN         Austria  Mar 16, 2020               NaN
# 1  132  Europe        NaN         Germany  Feb 01, 2020               NaN
# 2  578  Europe        NaN  United Kingdom  Mar 20, 2020               NaN
# 3  372  Europe        NaN  United Kingdom  Mar 16, 2020               NaN
# 4  357  Europe        NaN  United Kingdom  Mar 16, 2020               NaN
# 5  356  Europe        NaN  United Kingdom  Mar 16, 2020               NaN
# 6  373  Europe        NaN  United Kingdom  Mar 14, 2020               NaN
# 7  355  Europe        NaN  United Kingdom  Feb 26, 2020               NaN
# 8  603  Europe        NaN  United Kingdom  Mar 18, 2020      Apr 18, 2020
# 9  NaN    Asia        NaN         Vietnam           NaN               NaN
#
#                   Description of measure implemented Exceptions  \
# 0  On 10 March 2020 government announced that all...        NaN
# ...

# %%
cut_data.groupby('Region').describe()
# Out:
#        Quantity                              Target city       ...          \
#           count mean std min 25% 50% 75% max       count mean  ... 75% max
# Region                                                         ...
# Asia        0.0  NaN NaN NaN NaN NaN NaN NaN         0.0  NaN  ... NaN NaN
# Europe      0.0  NaN NaN NaN NaN NaN NaN NaN         0.0  NaN  ... NaN NaN
#
#        Target state
#               count mean std min 25% 50% 75% max
# Region
# Asia            0.0  NaN NaN NaN NaN NaN NaN NaN
# Europe          0.0  NaN NaN NaN NaN NaN NaN NaN
#
# [2 rows x 24 columns]

# %% [markdown]
# Saving results

# %%
cut_data.to_csv('output.csv', encoding = 'utf8')

# %%
stats.to_csv('stats.csv', encoding = 'utf8')
